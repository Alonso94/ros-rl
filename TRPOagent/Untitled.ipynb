# %%
import gym
import gym_crumb

# %%
env = gym.make('crumb-camera-v0')
# Out:
# WARN: Environment '<class 'gym_crumb.envs.crumb_camera_env.CrumbCameraEnv'>' has deprecated methods '_step' and '_reset' rather than 'step' and 'reset'. Compatibility code invoked. Set _gym_disable_underscore_compat = True to disable this behavior.

# %%
env.reset()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7F0E5560E400>
